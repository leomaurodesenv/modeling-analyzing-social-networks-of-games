# %% [markdown]
# # Association Rules - Analysis

# %%
# Imports
import pickle
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ### Data

# %%
support_min    = 0.05 # 36 elements
confidence_min = 0.5

# %%
# Data
dataset_folder = 'data'
data_norm = pd.read_csv('%s/%s' % (dataset_folder, 'platform-game-without-class.txt'), header=None, sep=' ')
columns = pickle.load(open('%s/%s' % (dataset_folder, 'platform-game-column.bin'), 'rb'))
df_clustering = pd.read_parquet('%s/%s' % (dataset_folder, 'cluster-items.parquet'))

df_clustering.head(10)
# Out:
#     cluster  coverage                                          dimension
# 120    2989        25  [harmful-breakable-flyBig, harmful-breakable-s...  \
# 110    2489        26  [harmful-breakable-shooterFlyBig, harmful-inde...
# 111    2532        26  [harmful-breakable-flyBig, harmful-breakable-s...
# 119    2542        25  [harmful-breakable-flyBig, harmful-indestructi...
# 125    1306        24  [harmful-breakable-flyBig, harmful-breakable-s...
# 106    1347        27  [harmful-breakable-flyBig, harmful-indestructi...
# 76     1620        38  [harmful-breakable-flyBig, harmful-breakable-s...
# 80     1250        32  [harmful-breakable-shooterBig, harmful-indestr...
# 83     1421        31  [harmful-breakable-flyBig, harmful-breakable-s...
# 89     1123        30  [harmful-breakable-shooterFlyBig, harmful-inde...
#
#                                          dimension.set
# 120  [harmful-breakable-flyBig, friendly-help, frie...  \
# 110  [friendly-coin, friendly-vehicle, harmful-brea...
# 111  [harmful-breakable-flyBig, friendly-help, frie...
# 119  [harmful-breakable-flyBig, friendly-coin, frie...
# 125  [harmful-breakable-shooterBig, harmful-breakab...
# 106  [harmful-breakable-flyBig, harmful-indestructi...
# 76   [harmful-breakable-shooterBig, friendly-telepo...
# 80   [harmful-breakable-shooterBig, harmful-indestr...
# 83   [harmful-breakable-shooterBig, harmful-indestr...
# 89   [friendly-vehicle, harmful-indestructible-shoo...
#
#                                               interval  dimension.size
# 120  [[0, 5], [0, 1], [0, 2], [6, 11], [0, 154], [0...               6
# 110      [[0, 1], [0, 2], [6, 11], [0, 154], [0, 250]]               5
# 111      [[0, 5], [0, 1], [6, 11], [0, 154], [0, 250]]               5
# 119      [[0, 5], [0, 2], [6, 11], [0, 154], [0, 250]]               5
# 125               [[0, 6], [0, 1], [35, 51], [0, 398]]               4
# 106                [[0, 5], [0, 2], [6, 11], [0, 250]]               4
# 76               [[0, 4], [0, 3], [206, 399], [0, 39]]               4
# 80                [[0, 5], [25, 36], [0, 2], [0, 176]]               4
# 83                [[0, 6], [0, 5], [25, 36], [0, 176]]               4
# 89                 [[0, 1], [0, 2], [6, 11], [0, 154]]               4

# %% [markdown]
# ## Cluster Analysis

# %%
# -- Without the dimensions (exclud)
def withoutDimension(df, exclud=[]):
    idxs, conds = [], []
    n = len(exclud)
    for idx, row in df.iterrows():
        idxs.append(idx)
        dims = [dim not in row['dimension'] for dim in exclud]
        conds.append(sum(dims) == n)
    print('without: %d' % sum(conds), exclud)
    return pd.Series(conds, index=idxs)


# -- With the dimensions (includ)
def withDimension(df, includ=[]):
    idxs, conds = [], []
    n = len(includ)
    for idx, row in df.iterrows():
        idxs.append(idx)
        dims = [dim in row['dimension'] for dim in includ]
        conds.append(sum(dims) == n)
    print('with: %d' % sum(conds), includ)
    return pd.Series(conds, index=idxs)

# %%
def unique(data):
    # intilize a null list 
    unique_list = [] 
    # traverse for all elements 
    for x in data: 
        # check if exists in unique_list or not 
        if set(x) not in unique_list: 
            unique_list.append(set(x))
        else:
            print(x)
    # return unique elements
    return unique_list

# %%
df_good = df_clustering[withoutDimension(df_clustering, ['friendly-help'])]

print()
cluster_itemset = unique(df_good['dimension.set'])

print('\nunique itemsets: %d' % len(cluster_itemset))
# Out:
# without: 18 ['friendly-help']
#
# ['harmful-breakable-flyBig' 'friendly-vehicle'
#  'harmful-indestructible-fixedBig']
# ['friendly-vehicle' 'harmful-indestructible-fixedBig']
# ['harmful-indestructible-shooter' 'friendly-vehicle']
#
# unique itemsets: 15

# %% [markdown]
# ## Association Rules Analysis
#
# ### Apriori
#
# Transactions

# %%
X = data_norm.astype(bool).copy()
X.columns = columns
X.head(3)
# Out:
#    harmful-breakable-walk  harmful-breakable-walkBig  harmful-breakable-fly
# 0                    True                       True                  False  \
# 1                   False                      False                  False
# 2                    True                      False                  False
#
#    harmful-breakable-flyBig  harmful-breakable-shooter
# 0                      True                      False  \
# 1                     False                      False
# 2                     False                      False
#
#    harmful-breakable-shooterBig  harmful-breakable-shooterFly
# 0                         False                         False  \
# 1                         False                         False
# 2                         False                         False
#
#    harmful-breakable-shooterFlyBig  harmful-indestructible-fixed
# 0                            False                          True  \
# 1                            False                          True
# 2                            False                         False
#
#    harmful-indestructible-fixedBig  ...  harmful-indestructible-shooterFly
# 0                            False  ...                              False  \
# 1                             True  ...                              False
# 2                            False  ...                              False
#
#    harmful-indestructible-shooterFlyBig  friendly-powerUp  friendly-vehicle
# 0                                 False             False             False  \
# 1                                 False             False             False
# 2                                 False              True             False
#
#    friendly-help  friendly-jump  friendly-move  friendly-teleport
# 0          False          False           True              False  \
# 1           True          False           True               True
# 2           True           True           True               True
#
#    friendly-puzzle  friendly-coin
# 0            False          False
# 1            False           True
# 2             True           True
#
# [3 rows x 26 columns]

# %%
# execution
frequent_itemsets = apriori(X, min_support=support_min, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

# orderned itemsets
print('itemsets: %d (<= %.2f)' % (len(frequent_itemsets),support_min))
frequent_itemsets.sort_values(by=['support'], ascending=False).head()
# Out:
# itemsets: 93825 (<= 0.05)
#      support                        itemsets  length
# 7   0.877778  (harmful-indestructible-fixed)       1
# 20  0.845833             (friendly-teleport)       1
# 17  0.830556                 (friendly-help)       1
# 19  0.826389                 (friendly-move)       1
# 22  0.777778                 (friendly-coin)       1

# %%
#frequent_itemsets[frequent_itemsets['itemsets'].isin(cluster_itemset)]
common_itemsets = pd.DataFrame(columns=frequent_itemsets.columns)
for idx,row in frequent_itemsets.iterrows():
    if row['itemsets'] in cluster_itemset:
        common_itemsets.loc[idx] = row
common_itemsets = common_itemsets.sort_values(by=['support'], ascending=False)

# %%
print('common itemsets:', len(common_itemsets))
common_itemsets
# Out:
# common itemsets: 7
#       support                                           itemsets length
# 149  0.341667   (harmful-indestructible-fixed, friendly-vehicle)      2
# 163  0.268056  (harmful-indestructible-fixedBig, friendly-veh...      2
# 218  0.268056  (harmful-indestructible-shooter, friendly-vehi...      2
# 770  0.077778  (harmful-breakable-flyBig, harmful-indestructi...      3
# 782  0.070833  (harmful-breakable-flyBig, harmful-indestructi...      3
# 833  0.070833  (harmful-breakable-flyBig, friendly-coin, frie...      3
# 978  0.058333  (harmful-breakable-shooterBig, harmful-indestr...      3

# %% [markdown]
# Add sub-itemsets of the common itemsets

# %%
from itertools import chain, combinations

# -- elaborate all subsets of N > size >= 1
def all_subsets(ss):
    return chain(*map(lambda x: combinations(ss, x), range(1, len(ss))))

for idx,row in common_itemsets.iterrows():
    ss = row['itemsets']
    for subset in all_subsets(ss):
        subset_itemsets = set(subset)
        tmp = frequent_itemsets[frequent_itemsets['itemsets'] == subset_itemsets]
        idx2, tmp = tmp.index[0], tmp.iloc[0]
        common_itemsets.loc[idx2] = tmp

# %%
# rules by metric
rules = association_rules(common_itemsets, metric='confidence', min_threshold=confidence_min)
rules_columns = ['antecedents','consequents','support','confidence','lift','conviction','leverage']

# %%
rules = rules.sort_values(by=['confidence'], ascending=False).reset_index(drop=True)
print('rules:', len(rules))
rules[rules_columns]
# Out:
# rules: 20
#                                           antecedents
# 0    (harmful-breakable-shooterBig, friendly-vehicle)  \
# 1                      (harmful-breakable-shooterBig)
# 2        (harmful-breakable-flyBig, friendly-vehicle)
# 3                                  (friendly-vehicle)
# 4                          (harmful-breakable-flyBig)
# 5        (harmful-breakable-flyBig, friendly-vehicle)
# 6        (harmful-breakable-flyBig, friendly-vehicle)
# 7                                  (friendly-vehicle)
# 8                          (harmful-breakable-flyBig)
# 9                          (harmful-breakable-flyBig)
# 10                                 (friendly-vehicle)
# 11                                 (friendly-vehicle)
# 12  (harmful-breakable-flyBig, harmful-indestructi...
# 13  (harmful-breakable-flyBig, harmful-indestructi...
# 14          (harmful-breakable-flyBig, friendly-coin)
# 15                         (harmful-breakable-flyBig)
# 16                         (harmful-breakable-flyBig)
# 17  (harmful-breakable-shooterBig, harmful-indestr...
# 18                     (harmful-breakable-shooterBig)
# 19                     (harmful-breakable-shooterBig)
#
#                                          consequents   support  confidence
# 0                     (harmful-indestructible-fixed)  0.058333    1.000000  \
# 1                     (harmful-indestructible-fixed)  0.112500    0.975904
# 2                     (harmful-indestructible-fixed)  0.077778    0.965517
# 3                     (harmful-indestructible-fixed)  0.341667    0.928302
# 4                     (harmful-indestructible-fixed)  0.137500    0.916667
# 5                                    (friendly-coin)  0.070833    0.879310
# 6                  (harmful-indestructible-fixedBig)  0.070833    0.879310
# 7                                    (friendly-coin)  0.315278    0.856604
# 8                                    (friendly-coin)  0.127778    0.851852
# 9                  (harmful-indestructible-fixedBig)  0.116667    0.777778
# 10                 (harmful-indestructible-fixedBig)  0.268056    0.728302
# 11                  (harmful-indestructible-shooter)  0.268056    0.728302
# 12                                (friendly-vehicle)  0.070833    0.607143
# 13                                (friendly-vehicle)  0.077778    0.565657
# 14                                (friendly-vehicle)  0.070833    0.554348
# 15                                (friendly-vehicle)  0.080556    0.537037
# 16  (harmful-indestructible-fixed, friendly-vehicle)  0.077778    0.518519
# 17                                (friendly-vehicle)  0.058333    0.518519
# 18  (harmful-indestructible-fixed, friendly-vehicle)  0.058333    0.506024
# 19                                (friendly-vehicle)  0.058333    0.506024
#
#         lift  conviction  leverage
# 0   1.139241         inf  0.007130
# 1   1.111789    5.072222  0.011312
# 2   1.099956    3.544444  0.007068
# 3   1.057559    1.704678  0.018596
# 4   1.044304    1.466667  0.005833
# 5   1.130542    1.841270  0.008179
# 6   1.394501    3.061111  0.020039
# 7   1.101348    1.549708  0.029012
# 8   1.095238    1.500000  0.011111
# 9   1.233480    1.662500  0.022083
# 10  1.155016    1.359761  0.035976
# 11  1.225181    1.492670  0.049267
# 12  1.649596    1.608586  0.027894
# 13  1.536878    1.454942  0.027170
# 14  1.506153    1.418022  0.023804
# 15  1.459119    1.365000  0.025347
# 16  1.517615    1.367308  0.026528
# 17  1.408805    1.312500  0.016927
# 18  1.481046    1.332724  0.018947
# 19  1.374858    1.279302  0.015905
